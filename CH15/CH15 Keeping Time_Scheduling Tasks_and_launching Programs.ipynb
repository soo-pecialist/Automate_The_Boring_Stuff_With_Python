# %% [markdown]
# ## The time Module

# %%
import time
time.time()
# Out:
# 1566781918.263208

# %%
def calc_prod():
    # Calculate the product of the first 100,000 numbers. 
    product = 1
    for i in range(1, 100000):
        product = product * i
    return product

start_time = time.time()
prod = calc_prod()
end_time = time.time()
print('The result is {} digits long.'.format(len(str(prod))))
print('Took {} seconds to calculate.'.format(end_time - start_time))
# Out:
# The result is 456569 digits long.
# Took 2.353996753692627 seconds to calculate.

# %%
for i in range(3):
    print('Tick')
    time.sleep(1)
    print('Tock')
    time.sleep(1)
# Out:
# Tick
# Tock
# Tick
# Tock
# Tick
# Tock

# %% [markdown]
# ## Project: Super Stopwatch

# %%
# %load stopwatch.py
#!/usr/bin/env python3
"""
Created on Sun Aug 25 21:15:18 2019

@author: Soo Hyeon Kim
A simple stopwatch program.
"""

import time

# Display the program's instructions.
input('Press ENTER to begin. Afterwards, press ENTER to "click" the stopwatch'
      'Press Ctrl-C to quit. or simply type "q" or "quit"')
print('\nStarted.')
start_time = time.time()
last_time = start_time
lap_num = 1

# TODO: Start tracking the lap time.
try:
    while True:
        
        input_ = input()
        lap_time = round(time.time() - last_time, 2)
        total_time = round(time.time() - start_time, 2)
        print('Lap #{}: {} ({})'.format(lap_num, total_time, lap_time, end=''))
        
        if input_.lower() in ['quit', 'q']:
            break
              
        lap_num += 1
        last_time = time.time()
        
except KeyboardInterrupt:
    # Handle the Ctrl-C exception to keep its error message from displaying.
    print('\nDone.')
# Out:
# Press ENTER to begin. Afterwards, press ENTER to "click" the stopwatchPress Ctrl-C to quit. or simply type "q" or "quit"
#
# Started.
#
# Lap #1: 2.74 (2.74)
#
# Lap #2: 6.14 (3.4)
#
# Lap #3: 12.74 (6.6)
#
# Lap #4: 19.63 (6.89)
#
# Lap #5: 25.46 (5.83)
#
# Lap #6: 42.06 (16.6)
# quit
# Lap #7: 45.29 (3.23)

# %% [markdown]
# ## The datetime Module

# %%
import datetime
datetime.datetime.now()
# Out:
# datetime.datetime(2019, 8, 25, 21, 43, 28, 18694)

# %%
dt = datetime.datetime(2015, 10, 21, 16, 29, 0)
dt.year, dt.month, dt.day
# Out:
# (2015, 10, 21)

# %%
dt.hour, dt.minute, dt.second
# Out:
# (16, 29, 0)

# %%
datetime.datetime.fromtimestamp(1000000)
# Out:
# datetime.datetime(1970, 1, 12, 8, 46, 40)

# %%
datetime.datetime.fromtimestamp(time.time())
# Out:
# datetime.datetime(2019, 8, 25, 21, 46, 15, 99829)

# %% [markdown]
# ## Converting datetime objects into strings

# %%
aug25th = datetime.datetime(2019, 8, 25, 10, 2, 0)
aug25th.strftime('%Y/%m/%d %H:%M:%S')
# Out:
# '2019/08/25 10:02:00'

# %% [markdown]
# ## Converting Strings into datetime Objects

# %%
datetime.datetime.strptime('October 21, 2015', '%B %d, %Y')
# Out:
# datetime.datetime(2015, 10, 21, 0, 0)

# %%
datetime.datetime.strptime('2015/10/21 16:29:00', '%Y/%m/%d %H:%M:%S')
# Out:
# datetime.datetime(2015, 10, 21, 16, 29)

# %%
datetime.datetime.strptime('October of \'15', "%B of '%y")
# Out:
# datetime.datetime(2015, 10, 1, 0, 0)

# %%
datetime.datetime.strptime("November of '63", "%B of '%y")
# Out:
# datetime.datetime(2063, 11, 1, 0, 0)

# %% [markdown]
# ## Multithreading

# %%
import threading, time
print('Start of program.')

def take_a_nap():
    time.sleep(5)
    print('Wake Up!')

thread = threading.Thread(target=take_a_nap)
thread.start()

print('End of program.')
# Out:
# Start of program.
# End of program.
# Wake Up!

# %% [markdown]
# ## Passing Arguments to the Thread's Target Function

# %%
print('Cats', 'Dogs', 'Frogs', sep=' & ')
# Out:
# Cats & Dogs & Frogs

# %%
thread = threading.Thread(target=print, args=['Cats', 'Dogs', 'Frog'], kwargs={'sep': ' & '})

# %%
thread.start()
# Out:
# Cats & Dogs & Frog

# %% [markdown]
# # Practice Project
#
# ## Project: Multithreaded XKCD Downloader

# %%
# %load multidownload_xkcd.py
#!/usr/bin/env python3
"""
Created on Sun Aug 25 23:15:21 2019

@author: Soo Hyeon Kim
Downloads XKCD comics using multiple threads.
"""

import requests, os, bs4, threading

os.makedirs('xkcd', exist_ok=True)  # store comics in ./xkcd

def download_xkcd(start_comic, end_comic):
    for url_number in range(start_comic, end_comic+1):
        # Download the page.
        print("Downloading page http://xkcd.com{} ...".format(url_number))
        res = requests.get('http://xkcd.com/{}'.format(url_number))
        res.raise_for_status()
        
        soup = bs4.BeautifulSoup(res.text)
        
        # Find the URL of the comic image.
        comic_elem = soup.select('#comic img')
        if comic_elem == []:
            print('Could not find comic image.')
        else:
            comic_url = comic_elem[0].get('src')
            # Download the image.
            print('Downloading image {} ...'.format(comic_url))
            
            try:
                res = requests.get(comic_url)
            except Exception as ecc:
                print('There was a problem: {}'.format(ecc))
            
            try:
                res.raise_for_status()
            except Exception as ecc:
                print('There was a problem: {}'.format(ecc))
            
            # Save the image to ./xkcd.
            image_file = open(os.path.join('xkcd', os.path.basename(comic_url)), 'wb')
            for chunk in res.iter_content(100000):
                image_file.write(chunk)
            image_file.close()
    
# TODO: Create and start the Thread objects.
download_threads = []       # a list of all the Thread objects
for i in range(0, 1400, 100):       # loops 14 times, creates 14 threads
    download_thread = threading.Thread(target=download_xkcd, args=(i, i+99))
    download_threads.append(download_thread)
    download_thread.start()            
    
# TODO: wait for all threads to end.
for download_thread in download_threads:
    download_thread.join() ## VERY IMPORTANT

print('\nDone.')
# Out:
# Downloading page http://xkcd.com0 ...
# Downloading page http://xkcd.com100 ...
# Downloading page http://xkcd.com200 ...
# Downloading page http://xkcd.com300 ...
# Downloading page http://xkcd.com400 ...Downloading page http://xkcd.com500 ...
#
# Downloading page http://xkcd.com600 ...
# Downloading page http://xkcd.com700 ...Downloading page http://xkcd.com800 ...
# Downloading page http://xkcd.com900 ...
#
# Downloading page http://xkcd.com1000 ...
# Downloading page http://xkcd.com1100 ...
# Downloading page http://xkcd.com1200 ...
# Downloading page http://xkcd.com1300 ...
# Downloading image //imgs.xkcd.com/comics/authorization.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/authorization.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/authorization.png?
# Downloading page http://xkcd.com1201 ...
# Downloading image //imgs.xkcd.com/comics/galilean_moons.png ...
# Downloading image //imgs.xkcd.com/comics/beautiful_dream.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/beautiful_dream.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/beautiful_dream.png?
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/galilean_moons.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/galilean_moons.png?
# Downloading page http://xkcd.com801 ...
# Downloading page http://xkcd.com1301 ...
# Downloading image //imgs.xkcd.com/comics/1000_comics.png ...
# Downloading image //imgs.xkcd.com/comics/religions.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/1000_comics.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/1000_comics.png?There was a problem: Invalid URL '//imgs.xkcd.com/comics/religions.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/religions.png?
#
# Downloading page http://xkcd.com901 ...Downloading page http://xkcd.com1001 ...
# Exception in thread Thread-7:
# Traceback (most recent call last):
#   File "/anaconda3/lib/python3.6/threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "/anaconda3/lib/python3.6/threading.py", line 864, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-24-94dacebabbdf>", line 19, in download_xkcd
#     res.raise_for_status()
#   File "/anaconda3/lib/python3.6/site-packages/requests/models.py", line 940, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 404 Client Error: Not Found for url: https://xkcd.com/0
# Downloading image //imgs.xkcd.com/comics/important_life_lesson.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/important_life_lesson.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/important_life_lesson.png?
# Downloading page http://xkcd.com401 ...
# Downloading image //imgs.xkcd.com/comics/integration_by_parts.png ...
# Downloading image //imgs.xkcd.com/comics/golden_hammer.png ...
# Downloading image //imgs.xkcd.com/comics/bill_nye.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/integration_by_parts.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/integration_by_parts.png?There was a problem: Invalid URL '//imgs.xkcd.com/comics/golden_hammer.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/golden_hammer.png?
#
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/bill_nye.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/bill_nye.png?
# Downloading page http://xkcd.com1202 ...Downloading image //imgs.xkcd.com/comics/election.png ...
#
# Downloading page http://xkcd.com201 ...Downloading page http://xkcd.com802 ...There was a problem: Invalid URL '//imgs.xkcd.com/comics/election.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/election.png?
#
#
# Downloading page http://xkcd.com501 ...Downloading image //imgs.xkcd.com/comics/file_extensions.png ...
#
# Downloading image //imgs.xkcd.com/comics/family_circus.jpg ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/family_circus.jpg': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/family_circus.jpg?
# Downloading page http://xkcd.com101 ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/file_extensions.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/file_extensions.png?
# Downloading page http://xkcd.com1302 ...
# Downloading image //imgs.xkcd.com/comics/aaaaaa.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/aaaaaa.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/aaaaaa.png?
# Downloading image //imgs.xkcd.com/comics/vows.png ...
# Downloading page http://xkcd.com1002 ...
# Downloading image //imgs.xkcd.com/comics/android_boyfriend.png ...Downloading image //imgs.xkcd.com/comics/temperature.png ...
#
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/vows.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/vows.png?
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/android_boyfriend.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/android_boyfriend.png?
# Downloading image //imgs.xkcd.com/comics/facebook.png ...Downloading page http://xkcd.com1101 ...
#
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/temperature.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/temperature.png?
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/facebook.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/facebook.png?
# Downloading page http://xkcd.com601 ...
# Downloading page http://xkcd.com301 ...
# Downloading page http://xkcd.com902 ...
# Downloading image //imgs.xkcd.com/comics/complexion.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/complexion.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/complexion.png?
# Downloading page http://xkcd.com701 ...
# Downloading image //imgs.xkcd.com/comics/large_hadron_collider.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/large_hadron_collider.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/large_hadron_collider.png?
# Downloading page http://xkcd.com402 ...
# Downloading image //imgs.xkcd.com/comics/science_valentine.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/science_valentine.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/science_valentine.png?
# Downloading page http://xkcd.com702 ...
# Downloading image //imgs.xkcd.com/comics/darmok_and_jalad.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/darmok_and_jalad.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/darmok_and_jalad.png?
# Downloading page http://xkcd.com903 ...
# Downloading image //imgs.xkcd.com/comics/laser_scope.jpg ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/laser_scope.jpg': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/laser_scope.jpg?
# Downloading page http://xkcd.com102 ...
# Downloading image //imgs.xkcd.com/comics/year_in_review.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/year_in_review.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/year_in_review.png?
# Downloading page http://xkcd.com1303 ...
# Downloading image //imgs.xkcd.com/comics/faust_20.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/faust_20.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/faust_20.png?
# Downloading page http://xkcd.com502 ...
# Downloading image //imgs.xkcd.com/comics/sketchiness.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/sketchiness.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/sketchiness.png?
# Downloading page http://xkcd.com1102 ...
# Downloading image //imgs.xkcd.com/comics/game_ais.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/game_ais.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/game_ais.png?
# Downloading page http://xkcd.com1003 ...
# Downloading image //imgs.xkcd.com/comics/limerick.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/limerick.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/limerick.png?
# Downloading page http://xkcd.com302 ...
# Downloading image //imgs.xkcd.com/comics/1000_miles_north.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/1000_miles_north.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/1000_miles_north.png?
# Downloading page http://xkcd.com403 ...
# Downloading image //imgs.xkcd.com/comics/game_theory.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/game_theory.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/game_theory.png?
# Downloading page http://xkcd.com602 ...
# Downloading image //imgs.xkcd.com/comics/online_communities_2.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/online_communities_2.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/online_communities_2.png?
# Downloading page http://xkcd.com803 ...
# Downloading image //imgs.xkcd.com/comics/christmas_gps.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/christmas_gps.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/christmas_gps.png?
# Downloading page http://xkcd.com202 ...
# Downloading image //imgs.xkcd.com/comics/dark_flow.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/dark_flow.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/dark_flow.png?
# Downloading page http://xkcd.com503 ...
# Downloading image //imgs.xkcd.com/comics/snow_tracking.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/snow_tracking.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/snow_tracking.png?
# Downloading page http://xkcd.com703 ...
# Downloading image //imgs.xkcd.com/comics/extended_mind.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/extended_mind.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/extended_mind.png?
# Downloading page http://xkcd.com904 ...
# Downloading image //imgs.xkcd.com/comics/adam_and_eve.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/adam_and_eve.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/adam_and_eve.png?
# Downloading page http://xkcd.com1004 ...
# Downloading image //imgs.xkcd.com/comics/convincing_pickup_line.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/convincing_pickup_line.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/convincing_pickup_line.png?
# Downloading page http://xkcd.com404 ...
# Downloading image //imgs.xkcd.com/comics/names.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/names.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/names.png?
# Downloading page http://xkcd.com303 ...
# Downloading image //imgs.xkcd.com/comics/profile_info.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/profile_info.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/profile_info.png?
# Downloading page http://xkcd.com1304 ...
# Downloading image //imgs.xkcd.com/comics/airfoil.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/airfoil.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/airfoil.png?
# Downloading page http://xkcd.com804 ...
# Downloading image //imgs.xkcd.com/comics/overstimulated.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/overstimulated.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/overstimulated.png?
# Downloading page http://xkcd.com603 ...
# Downloading image //imgs.xkcd.com/comics/girls_and_boys.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/girls_and_boys.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/girls_and_boys.png?
# Downloading image //imgs.xkcd.com/comics/youtube.png ...
# Downloading page http://xkcd.com1203 ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/youtube.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/youtube.png?
# Downloading page http://xkcd.com203 ...Downloading image //imgs.xkcd.com/comics/back_to_the_future.jpg ...
#
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/back_to_the_future.jpg': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/back_to_the_future.jpg?
# Downloading page http://xkcd.com103 ...
# Downloading image //imgs.xkcd.com/comics/fastest_growing.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/fastest_growing.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/fastest_growing.png?
# Downloading page http://xkcd.com1103 ...
# Downloading image //imgs.xkcd.com/comics/time_machines.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/time_machines.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/time_machines.png?
# Downloading page http://xkcd.com1204 ...
# Downloading image //imgs.xkcd.com/comics/idiocracy.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/idiocracy.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/idiocracy.png?
# Downloading page http://xkcd.com604 ...
# Downloading image //imgs.xkcd.com/comics/hallucinations.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/hallucinations.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/hallucinations.png?
# Downloading page http://xkcd.com204 ...
# Downloading image //imgs.xkcd.com/comics/nine.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/nine.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/nine.png?
# Downloading page http://xkcd.com1104 ...
# Downloading image //imgs.xkcd.com/comics/pumpkin_carving.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/pumpkin_carving.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/pumpkin_carving.png?
# Downloading page http://xkcd.com805 ...
# Downloading image //imgs.xkcd.com/comics/moral_relativity.jpg ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/moral_relativity.jpg': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/moral_relativity.jpg?
# Downloading page http://xkcd.com104 ...
# Downloading image //imgs.xkcd.com/comics/honor_societies.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/honor_societies.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/honor_societies.png?
# Downloading page http://xkcd.com704 ...
# Downloading image //imgs.xkcd.com/comics/sports.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/sports.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/sports.png?
# Downloading page http://xkcd.com905 ...
# Downloading image //imgs.xkcd.com/comics/batman.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/batman.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/batman.png?
# Downloading page http://xkcd.com1005 ...
# Downloading image //imgs.xkcd.com/comics/compiling.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/compiling.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/compiling.png?
# Downloading page http://xkcd.com304 ...
# Downloading image //imgs.xkcd.com/comics/glass_trolling.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/glass_trolling.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/glass_trolling.png?
# Downloading page http://xkcd.com1305 ...
# Exception in thread Thread-11:
# Traceback (most recent call last):
#   File "/anaconda3/lib/python3.6/threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "/anaconda3/lib/python3.6/threading.py", line 864, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-24-94dacebabbdf>", line 19, in download_xkcd
#     res.raise_for_status()
#   File "/anaconda3/lib/python3.6/site-packages/requests/models.py", line 940, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 404 Client Error: Not Found for url: https://xkcd.com/404
# Downloading image //imgs.xkcd.com/comics/terminology.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/terminology.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/terminology.png?
# Downloading page http://xkcd.com504 ...
# Downloading image //imgs.xkcd.com/comics/detail.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/detail.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/detail.png?
# Downloading page http://xkcd.com1205 ...
# Downloading image //imgs.xkcd.com/comics/qwertial_aphasia.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/qwertial_aphasia.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/qwertial_aphasia.png?
# Downloading page http://xkcd.com605 ...
# Downloading image //imgs.xkcd.com/comics/america.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/america.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/america.png?
# Downloading page http://xkcd.com205 ...
# Downloading image //imgs.xkcd.com/comics/feathers.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/feathers.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/feathers.png?
# Downloading page http://xkcd.com1105 ...
# Downloading image //imgs.xkcd.com/comics/legal_hacks.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/legal_hacks.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/legal_hacks.png?
# Downloading page http://xkcd.com505 ...
# Downloading image //imgs.xkcd.com/comics/paradise_city.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/paradise_city.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/paradise_city.png?
# Downloading page http://xkcd.com806 ...
# Downloading image //imgs.xkcd.com/comics/undocumented_feature.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/undocumented_feature.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/undocumented_feature.png?
# Downloading page http://xkcd.com1306 ...
# Downloading image //imgs.xkcd.com/comics/candy_button_paper.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/candy_button_paper.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/candy_button_paper.png?
# Downloading page http://xkcd.com206 ...
# Downloading image //imgs.xkcd.com/comics/principle_of_explosion.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/principle_of_explosion.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/principle_of_explosion.png?
# Downloading page http://xkcd.com705 ...
# Downloading image //imgs.xkcd.com/comics/tech_support.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/tech_support.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/tech_support.png?
# Downloading page http://xkcd.com807 ...
# Downloading image //imgs.xkcd.com/comics/license_plate.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/license_plate.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/license_plate.png?
# Downloading image //imgs.xkcd.com/comics/find_you.jpg ...Downloading page http://xkcd.com1106 ...
#
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/find_you.jpg': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/find_you.jpg?
# Downloading page http://xkcd.com105 ...
# Downloading image //imgs.xkcd.com/comics/extrapolating.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/extrapolating.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/extrapolating.png?
# Downloading page http://xkcd.com606 ...
# Downloading image //imgs.xkcd.com/comics/is_it_worth_the_time.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/is_it_worth_the_time.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/is_it_worth_the_time.png?
# Downloading page http://xkcd.com1206 ...
# Downloading image //imgs.xkcd.com/comics/homeownership.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/homeownership.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/homeownership.png?
# Downloading page http://xkcd.com906 ...
# Downloading image //imgs.xkcd.com/comics/sopa.png ...
# Downloading image //imgs.xkcd.com/comics/reno_rhymes.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/sopa.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/sopa.png?
# Downloading page http://xkcd.com1006 ...There was a problem: Invalid URL '//imgs.xkcd.com/comics/reno_rhymes.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/reno_rhymes.png?
#
# Downloading page http://xkcd.com207 ...
# Downloading image //imgs.xkcd.com/comics/a_bunch_of_rocks.png ...
# Downloading image //imgs.xkcd.com/comics/sigil_cycle.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/a_bunch_of_rocks.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/a_bunch_of_rocks.png?
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/sigil_cycle.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/sigil_cycle.png?
# Downloading page http://xkcd.com506 ...
# Downloading page http://xkcd.com1307 ...
# Downloading image //imgs.xkcd.com/comics/nighttime_stories.jpg ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/nighttime_stories.jpg': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/nighttime_stories.jpg?
# Downloading page http://xkcd.com305 ...
# Downloading image //imgs.xkcd.com/comics/connected.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/connected.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/connected.png?
# Downloading page http://xkcd.com808 ...
# Downloading image //imgs.xkcd.com/comics/devotion_to_duty.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/devotion_to_duty.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/devotion_to_duty.png?
# Downloading page http://xkcd.com706 ...
# Downloading image //imgs.xkcd.com/comics/add.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/add.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/add.png?
# Downloading page http://xkcd.com1107 ...
# Downloading image //imgs.xkcd.com/comics/parallel_universe.jpg ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/parallel_universe.jpg': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/parallel_universe.jpg?
# Downloading page http://xkcd.com106 ...
# Downloading image //imgs.xkcd.com/comics/citations.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/citations.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/citations.png?
# Downloading page http://xkcd.com907 ...
# Downloading image //imgs.xkcd.com/comics/sloppier_than_fiction.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/sloppier_than_fiction.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/sloppier_than_fiction.png?
# Downloading page http://xkcd.com1007 ...
# Downloading image //imgs.xkcd.com/comics/rule_34.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/rule_34.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/rule_34.png?
# Downloading image //imgs.xkcd.com/comics/the_economic_argument.png ...
# Downloading image //imgs.xkcd.com/comics/sports_cheat_sheet.png ...
# Downloading page http://xkcd.com306 ...
# Downloading image //imgs.xkcd.com/comics/buzzfeed_christmas.png ...There was a problem: Invalid URL '//imgs.xkcd.com/comics/sports_cheat_sheet.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/sports_cheat_sheet.png?
#
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/the_economic_argument.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/the_economic_argument.png?
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/buzzfeed_christmas.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/buzzfeed_christmas.png?
# Downloading page http://xkcd.com1108 ...
# Downloading page http://xkcd.com1308 ...
# Downloading page http://xkcd.com809 ...
# Downloading image //imgs.xkcd.com/comics/theft_of_the_magi.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/theft_of_the_magi.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/theft_of_the_magi.png?
# Downloading page http://xkcd.com507 ...
# Downloading image //imgs.xkcd.com/comics/freedom.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/freedom.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/freedom.png?
# Downloading image //imgs.xkcd.com/comics/wright_brothers.png ...Downloading page http://xkcd.com707 ...
#
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/wright_brothers.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/wright_brothers.png?
# Downloading page http://xkcd.com107 ...
# Downloading image //imgs.xkcd.com/comics/cutting_edge.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/cutting_edge.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/cutting_edge.png?
# Downloading page http://xkcd.com607 ...
# Downloading image //imgs.xkcd.com/comics/einstein.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/einstein.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/einstein.png?
# Downloading page http://xkcd.com1207 ...
# Downloading image //imgs.xkcd.com/comics/ages.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/ages.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/ages.png?
# Downloading page http://xkcd.com908 ...
# Downloading image //imgs.xkcd.com/comics/what_xkcd_means.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/what_xkcd_means.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/what_xkcd_means.png?
# Downloading page http://xkcd.com208 ...
# Downloading image //imgs.xkcd.com/comics/sustainable.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/sustainable.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/sustainable.png?
# Downloading page http://xkcd.com1008 ...
# Downloading image //imgs.xkcd.com/comics/regular_expressions.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/regular_expressions.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/regular_expressions.png?
# Downloading page http://xkcd.com209 ...
# Downloading image //imgs.xkcd.com/comics/christmas_lights.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/christmas_lights.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/christmas_lights.png?
# Downloading page http://xkcd.com1309 ...
# Downloading image //imgs.xkcd.com/comics/orphaned_projects.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/orphaned_projects.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/orphaned_projects.png?
# Downloading page http://xkcd.com307 ...
# Downloading image //imgs.xkcd.com/comics/suckville.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/suckville.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/suckville.png?
# Downloading page http://xkcd.com1009 ...
# Downloading image //imgs.xkcd.com/comics/experimentation.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/experimentation.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/experimentation.png?
# Downloading page http://xkcd.com508 ...
# Downloading image //imgs.xkcd.com/comics/cautionary_ghost.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/cautionary_ghost.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/cautionary_ghost.png?
# Downloading image //imgs.xkcd.com/comics/los_alamos.png ...Downloading image //imgs.xkcd.com/comics/joshing.png ...
#
# Downloading page http://xkcd.com1109 ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/joshing.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/joshing.png?There was a problem: Invalid URL '//imgs.xkcd.com/comics/los_alamos.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/los_alamos.png?
#
# Downloading page http://xkcd.com810 ...Downloading page http://xkcd.com708 ...
#
# Downloading image //imgs.xkcd.com/comics/kayak.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/kayak.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/kayak.png?
# Downloading page http://xkcd.com210 ...
# Downloading image //imgs.xkcd.com/comics/snakes_on_a_plane_2.jpg ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/snakes_on_a_plane_2.jpg': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/snakes_on_a_plane_2.jpg?
# Downloading page http://xkcd.com108 ...
# Downloading image //imgs.xkcd.com/comics/airaware.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/airaware.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/airaware.png?
# Downloading page http://xkcd.com1208 ...
# Downloading image //imgs.xkcd.com/comics/2038.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/2038.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/2038.png?
# Downloading page http://xkcd.com608 ...
# Downloading image //imgs.xkcd.com/comics/the_cloud.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/the_cloud.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/the_cloud.png?
# Downloading page http://xkcd.com909 ...
# Downloading image //imgs.xkcd.com/comics/infinite_scrolling.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/infinite_scrolling.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/infinite_scrolling.png?
# Downloading page http://xkcd.com1310 ...
# Downloading image //imgs.xkcd.com/comics/excessive_quotation.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/excessive_quotation.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/excessive_quotation.png?
# Downloading page http://xkcd.com308 ...
# Downloading image //imgs.xkcd.com/comics/footnote_labyrinths.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/footnote_labyrinths.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/footnote_labyrinths.png?
# Downloading page http://xkcd.com1209 ...
# Downloading image //imgs.xkcd.com/comics/sigh.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/sigh.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/sigh.png?
# Downloading page http://xkcd.com1010 ...
# Downloading image //imgs.xkcd.com/comics/mc_hammer_slide.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/mc_hammer_slide.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/mc_hammer_slide.png?
# Downloading page http://xkcd.com109 ...
# Downloading image //imgs.xkcd.com/comics/drapes.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/drapes.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/drapes.png?
# Downloading page http://xkcd.com509 ...
# Downloading image //imgs.xkcd.com/comics/goldbach_conjectures.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/goldbach_conjectures.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/goldbach_conjectures.png?
# Downloading page http://xkcd.com1311 ...
# Downloading image //imgs.xkcd.com/comics/refrigerator.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/refrigerator.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/refrigerator.png?
# Downloading page http://xkcd.com1110 ...
# Downloading image //imgs.xkcd.com/comics/sex_dice.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/sex_dice.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/sex_dice.png?
# Downloading page http://xkcd.com709 ...
# Downloading image //imgs.xkcd.com/comics/constructive.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/constructive.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/constructive.png?
# Downloading page http://xkcd.com811 ...
# Downloading image //imgs.xkcd.com/comics/form.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/form.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/form.png?
# Downloading page http://xkcd.com609 ...
# Downloading image //imgs.xkcd.com/comics/etymology_man.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/etymology_man.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/etymology_man.png?
# Downloading page http://xkcd.com1011 ...
# Downloading image //imgs.xkcd.com/comics/90s_flowchart.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/90s_flowchart.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/90s_flowchart.png?
# Downloading page http://xkcd.com211 ...
# Downloading image //imgs.xkcd.com/comics/interesting_life.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/interesting_life.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/interesting_life.png?
# Downloading page http://xkcd.com309 ...
# Downloading image //imgs.xkcd.com/comics/spoiler_alert.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/spoiler_alert.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/spoiler_alert.png?
# Downloading page http://xkcd.com110 ...
# Downloading image //imgs.xkcd.com/comics/encoding.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/encoding.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/encoding.png?
# Downloading page http://xkcd.com1210 ...
# Downloading image //imgs.xkcd.com/comics/induced_current.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/induced_current.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/induced_current.png?
# Downloading page http://xkcd.com510 ...
# Downloading image //imgs.xkcd.com/comics/click_and_drag.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/click_and_drag.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/click_and_drag.png?
# Downloading page http://xkcd.com1111 ...
# Downloading image //imgs.xkcd.com/comics/2014.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/2014.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/2014.png?
# Downloading page http://xkcd.com1312 ...
# Downloading image //imgs.xkcd.com/comics/worst_case_shopping.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/worst_case_shopping.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/worst_case_shopping.png?
# Downloading page http://xkcd.com910 ...
# Downloading image //imgs.xkcd.com/comics/i_am.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/i_am.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/i_am.png?
# Downloading page http://xkcd.com710 ...
# Downloading image //imgs.xkcd.com/comics/starlight.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/starlight.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/starlight.png?
# Downloading page http://xkcd.com812 ...
# Downloading image //imgs.xkcd.com/comics/egg_drop_failure.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/egg_drop_failure.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/egg_drop_failure.png?
# Downloading page http://xkcd.com511 ...
# Downloading image //imgs.xkcd.com/comics/premiere.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/premiere.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/premiere.png?
# Downloading page http://xkcd.com1112 ...
# Downloading image //imgs.xkcd.com/comics/shopping_teams.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/shopping_teams.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/shopping_teams.png?
# Downloading page http://xkcd.com310 ...
# Downloading image //imgs.xkcd.com/comics/baby_names.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/baby_names.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/baby_names.png?
# Downloading page http://xkcd.com1012 ...
# Downloading image //imgs.xkcd.com/comics/clark_gable.jpg ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/clark_gable.jpg': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/clark_gable.jpg?
# Downloading page http://xkcd.com111 ...
# Downloading image //imgs.xkcd.com/comics/tab_explosion.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/tab_explosion.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/tab_explosion.png?
# Downloading page http://xkcd.com610 ...
# Downloading image //imgs.xkcd.com/comics/permanence.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/permanence.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/permanence.png?
# Downloading page http://xkcd.com911 ...
# Downloading image //imgs.xkcd.com/comics/hamster_ball_heist.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/hamster_ball_heist.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/hamster_ball_heist.png?
# Downloading page http://xkcd.com212 ...
# Downloading image //imgs.xkcd.com/comics/im_so_random.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/im_so_random.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/im_so_random.png?
# Downloading page http://xkcd.com1211 ...
# Downloading image //imgs.xkcd.com/comics/haskell.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/haskell.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/haskell.png?
# Downloading page http://xkcd.com1313 ...
# Downloading image //imgs.xkcd.com/comics/collatz_conjecture.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/collatz_conjecture.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/collatz_conjecture.png?
# Downloading page http://xkcd.com711 ...
# Downloading image //imgs.xkcd.com/comics/commitment.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/commitment.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/commitment.png?
# Downloading page http://xkcd.com311 ...
# Downloading image //imgs.xkcd.com/comics/sheeple.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/sheeple.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/sheeple.png?
# Downloading page http://xkcd.com611 ...
# Downloading image //imgs.xkcd.com/comics/magic_school_bus.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/magic_school_bus.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/magic_school_bus.png?
# Downloading image //imgs.xkcd.com/comics/wrong_superhero.png ...Downloading page http://xkcd.com912 ...
#
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/wrong_superhero.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/wrong_superhero.png?
# Downloading page http://xkcd.com1013 ...
# Downloading image //imgs.xkcd.com/comics/birds_and_dinosaurs.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/birds_and_dinosaurs.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/birds_and_dinosaurs.png?
# Downloading page http://xkcd.com1212 ...
# Downloading image //imgs.xkcd.com/comics/brain.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/brain.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/brain.png?
# Downloading page http://xkcd.com213 ...
# Downloading image //imgs.xkcd.com/comics/glass.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/glass.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/glass.png?
# Downloading page http://xkcd.com813 ...
# Downloading image //imgs.xkcd.com/comics/sleet.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/sleet.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/sleet.png?
# Downloading page http://xkcd.com512 ...
# Downloading image //imgs.xkcd.com/comics/think_logically.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/think_logically.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/think_logically.png?
# Downloading page http://xkcd.com1113 ...
# Downloading image //imgs.xkcd.com/comics/action_movies.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/action_movies.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/action_movies.png?
# Downloading page http://xkcd.com312 ...
# Downloading image //imgs.xkcd.com/comics/seismograph.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/seismograph.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/seismograph.png?
# Downloading page http://xkcd.com712 ...
# Downloading image //imgs.xkcd.com/comics/manual_override.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/manual_override.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/manual_override.png?
# Downloading page http://xkcd.com913 ...
# Downloading image //imgs.xkcd.com/comics/firefox_wicca.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/firefox_wicca.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/firefox_wicca.png?
# Downloading page http://xkcd.com112 ...
# Downloading image //imgs.xkcd.com/comics/interstellar_memes.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/interstellar_memes.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/interstellar_memes.png?
# Downloading page http://xkcd.com1213 ...
# Downloading image //imgs.xkcd.com/comics/disaster_voyeurism.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/disaster_voyeurism.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/disaster_voyeurism.png?
# Downloading page http://xkcd.com612 ...
# Downloading image //imgs.xkcd.com/comics/one_liners.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/one_liners.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/one_liners.png?
# Downloading page http://xkcd.com814 ...
# Downloading image //imgs.xkcd.com/comics/wake_up_sheeple.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/wake_up_sheeple.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/wake_up_sheeple.png?
# Downloading page http://xkcd.com1014 ...
# Downloading image //imgs.xkcd.com/comics/ghostbusters_marathon.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/ghostbusters_marathon.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/ghostbusters_marathon.png?
# Downloading page http://xkcd.com214 ...
# Downloading image //imgs.xkcd.com/comics/alternate_currency.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/alternate_currency.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/alternate_currency.png?
# Downloading page http://xkcd.com513 ...
# Downloading image //imgs.xkcd.com/comics/the_problem_with_wikipedia.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/the_problem_with_wikipedia.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/the_problem_with_wikipedia.png?
# Downloading page http://xkcd.com215 ...
# Downloading image //imgs.xkcd.com/comics/diode.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/diode.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/diode.png?
# Downloading page http://xkcd.com815 ...
# Downloading image //imgs.xkcd.com/comics/friends.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/friends.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/friends.png?
# Downloading page http://xkcd.com514 ...
# Downloading image //imgs.xkcd.com/comics/killed_in_action.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/killed_in_action.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/killed_in_action.png?
# Downloading page http://xkcd.com1114 ...
# Downloading image //imgs.xkcd.com/comics/baring_my_heart.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/baring_my_heart.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/baring_my_heart.png?
# Downloading page http://xkcd.com113 ...
# Downloading image //imgs.xkcd.com/comics/single_ladies.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/single_ladies.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/single_ladies.png?
# Downloading page http://xkcd.com713 ...
# Downloading image //imgs.xkcd.com/comics/with_apologies_to_robert_frost.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/with_apologies_to_robert_frost.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/with_apologies_to_robert_frost.png?
# Downloading page http://xkcd.com313 ...
# Downloading image //imgs.xkcd.com/comics/estimation.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/estimation.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/estimation.png?Downloading image //imgs.xkcd.com/comics/regex_golf.png ...
#
# Downloading page http://xkcd.com613 ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/regex_golf.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/regex_golf.png?
# Downloading page http://xkcd.com1314 ...
# Downloading image //imgs.xkcd.com/comics/mu.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/mu.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/mu.png?
# Downloading page http://xkcd.com816 ...
# Downloading image //imgs.xkcd.com/comics/combination_vision_test.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/combination_vision_test.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/combination_vision_test.png?
# Downloading page http://xkcd.com1214 ...
# Downloading image //imgs.xkcd.com/comics/core.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/core.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/core.png?
# Downloading page http://xkcd.com914 ...
# Downloading image //imgs.xkcd.com/comics/letting_go.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/letting_go.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/letting_go.png?
# Downloading page http://xkcd.com216 ...
# Downloading image //imgs.xkcd.com/comics/riemann-zeta.jpg ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/riemann-zeta.jpg': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/riemann-zeta.jpg?
# Downloading page http://xkcd.com114 ...
# Downloading image //imgs.xkcd.com/comics/car_problems.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/car_problems.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/car_problems.png?
# ...
# Downloading page http://xkcd.com1399 ...
# Downloading image //imgs.xkcd.com/comics/a_hypochondriacs_nightmare.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/a_hypochondriacs_nightmare.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/a_hypochondriacs_nightmare.png?
# Downloading page http://xkcd.com1098 ...
# Downloading image //imgs.xkcd.com/comics/ninja_turtles.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/ninja_turtles.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/ninja_turtles.png?
# Downloading page http://xkcd.com198 ...
# Downloading image //imgs.xkcd.com/comics/unsatisfied.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/unsatisfied.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/unsatisfied.png?
# Downloading page http://xkcd.com585 ...
# Downloading image //imgs.xkcd.com/comics/plastic_bags.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/plastic_bags.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/plastic_bags.png?
# Downloading page http://xkcd.com991 ...
# Downloading image //imgs.xkcd.com/comics/job_interview.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/job_interview.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/job_interview.png?
# Downloading page http://xkcd.com1294 ...
# Downloading image //imgs.xkcd.com/comics/spirit.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/spirit.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/spirit.png?
# Downloading page http://xkcd.com696 ...
# Downloading image //imgs.xkcd.com/comics/orbiter.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/orbiter.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/orbiter.png?
# Downloading page http://xkcd.com788 ...
# Downloading image //imgs.xkcd.com/comics/chain_of_command.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/chain_of_command.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/chain_of_command.png?
# Downloading page http://xkcd.com899 ...
# Downloading image //imgs.xkcd.com/comics/geologist.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/geologist.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/geologist.png?
# Downloading page http://xkcd.com1199 ...
# Downloading image //imgs.xkcd.com/comics/perspective.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/perspective.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/perspective.png?
# Downloading page http://xkcd.com199 ...
# Downloading image //imgs.xkcd.com/comics/star_ratings.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/star_ratings.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/star_ratings.png?
# Downloading page http://xkcd.com1099 ...
# Downloading image //imgs.xkcd.com/comics/silence.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/silence.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/silence.png?
# Downloading image //imgs.xkcd.com/comics/the_carriage.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/the_carriage.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/the_carriage.png?
# Downloading page http://xkcd.com789 ...
# Downloading image //imgs.xkcd.com/comics/right_hand_rule.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/right_hand_rule.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/right_hand_rule.png?
# Downloading image //imgs.xkcd.com/comics/number_line.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/number_line.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/number_line.png?
# Downloading image //imgs.xkcd.com/comics/strip_games.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/strip_games.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/strip_games.png?
# Downloading page http://xkcd.com697 ...
# Downloading image //imgs.xkcd.com/comics/tuesdays.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/tuesdays.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/tuesdays.png?
# Downloading image //imgs.xkcd.com/comics/telescope_names.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/telescope_names.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/telescope_names.png?
# Downloading page http://xkcd.com1295 ...
# Downloading image //imgs.xkcd.com/comics/phantom_menace.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/phantom_menace.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/phantom_menace.png?
# Downloading page http://xkcd.com992 ...
# Downloading image //imgs.xkcd.com/comics/showdown.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/showdown.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/showdown.png?
# Downloading page http://xkcd.com790 ...
# Downloading image //imgs.xkcd.com/comics/mnemonics.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/mnemonics.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/mnemonics.png?
# Downloading page http://xkcd.com993 ...
# Downloading image //imgs.xkcd.com/comics/tensile_vs_shear_strength.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/tensile_vs_shear_strength.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/tensile_vs_shear_strength.png?
# Downloading page http://xkcd.com698 ...
# Downloading image //imgs.xkcd.com/comics/new_study.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/new_study.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/new_study.png?
# Downloading page http://xkcd.com1296 ...
# Downloading image //imgs.xkcd.com/comics/outreach.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/outreach.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/outreach.png?
# Downloading page http://xkcd.com586 ...
# Downloading image //imgs.xkcd.com/comics/brand_identity.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/brand_identity.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/brand_identity.png?
# Downloading page http://xkcd.com994 ...
# Downloading image //imgs.xkcd.com/comics/mission_to_culture.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/mission_to_culture.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/mission_to_culture.png?
# Downloading image //imgs.xkcd.com/comics/you_hang_up_first.png ...
# Downloading page http://xkcd.com587 ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/you_hang_up_first.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/you_hang_up_first.png?
# Downloading page http://xkcd.com699 ...
# Downloading image //imgs.xkcd.com/comics/control.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/control.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/control.png?
# Downloading page http://xkcd.com791 ...
# Downloading image //imgs.xkcd.com/comics/advent_calendar.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/advent_calendar.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/advent_calendar.png?
# Downloading page http://xkcd.com995 ...
# Downloading image //imgs.xkcd.com/comics/crime_scene.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/crime_scene.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/crime_scene.png?
# Downloading page http://xkcd.com588 ...
# Downloading image //imgs.xkcd.com/comics/trimester.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/trimester.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/trimester.png?
# Downloading image //imgs.xkcd.com/comics/git_commit.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/git_commit.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/git_commit.png?
# Downloading page http://xkcd.com1297 ...
# Downloading image //imgs.xkcd.com/comics/leaving.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/leaving.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/leaving.png?
# Downloading page http://xkcd.com792 ...
# Downloading image //imgs.xkcd.com/comics/pep_rally.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/pep_rally.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/pep_rally.png?
# Downloading page http://xkcd.com589 ...
# Downloading image //imgs.xkcd.com/comics/password_reuse.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/password_reuse.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/password_reuse.png?
# Downloading page http://xkcd.com793 ...
# Downloading image //imgs.xkcd.com/comics/oort_cloud.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/oort_cloud.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/oort_cloud.png?
# Downloading page http://xkcd.com1298 ...
# Downloading image //imgs.xkcd.com/comics/chaos.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/chaos.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/chaos.png?
# Downloading image //imgs.xkcd.com/comics/designated_drivers.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/designated_drivers.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/designated_drivers.png?
# Downloading page http://xkcd.com590 ...
# Downloading image //imgs.xkcd.com/comics/coinstar.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/coinstar.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/coinstar.png?
# Downloading page http://xkcd.com996 ...
# Downloading image //imgs.xkcd.com/comics/physicists.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/physicists.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/physicists.png?
# Downloading page http://xkcd.com794 ...
# Downloading image //imgs.xkcd.com/comics/exoplanet_neighborhood.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/exoplanet_neighborhood.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/exoplanet_neighborhood.png?
# Downloading page http://xkcd.com1299 ...
# Downloading image //imgs.xkcd.com/comics/papyrus.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/papyrus.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/papyrus.png?
# Downloading page http://xkcd.com591 ...
# Downloading image //imgs.xkcd.com/comics/inside_joke.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/inside_joke.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/inside_joke.png?
# Downloading page http://xkcd.com795 ...
# Downloading image //imgs.xkcd.com/comics/i_dont_own_a_tv.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/i_dont_own_a_tv.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/i_dont_own_a_tv.png?
# Downloading image //imgs.xkcd.com/comics/making_things_difficult.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/making_things_difficult.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/making_things_difficult.png?
# Downloading page http://xkcd.com997 ...
# Downloading image //imgs.xkcd.com/comics/troll_slayer.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/troll_slayer.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/troll_slayer.png?
# Downloading page http://xkcd.com592 ...
# Downloading image //imgs.xkcd.com/comics/wait_wait.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/wait_wait.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/wait_wait.png?
# Downloading page http://xkcd.com998 ...
# Downloading image //imgs.xkcd.com/comics/drama.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/drama.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/drama.png?
# Downloading page http://xkcd.com593 ...
# Downloading image //imgs.xkcd.com/comics/2012.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/2012.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/2012.png?
# Downloading page http://xkcd.com999 ...
# Downloading image //imgs.xkcd.com/comics/voynich_manuscript.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/voynich_manuscript.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/voynich_manuscript.png?
# Downloading page http://xkcd.com594 ...
# Downloading image //imgs.xkcd.com/comics/cougars.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/cougars.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/cougars.png?
# Downloading image //imgs.xkcd.com/comics/period.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/period.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/period.png?
# Downloading page http://xkcd.com595 ...
# Downloading image //imgs.xkcd.com/comics/conditional_risk.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/conditional_risk.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/conditional_risk.png?
# Downloading page http://xkcd.com796 ...
# Downloading image //imgs.xkcd.com/comics/android_girlfriend.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/android_girlfriend.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/android_girlfriend.png?
# Downloading page http://xkcd.com596 ...
# Downloading image //imgs.xkcd.com/comics/bad_ex.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/bad_ex.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/bad_ex.png?
# Downloading page http://xkcd.com797 ...
# Downloading image //imgs.xkcd.com/comics/latitude.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/latitude.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/latitude.png?
# Downloading page http://xkcd.com597 ...
# Downloading image //imgs.xkcd.com/comics/debian_main.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/debian_main.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/debian_main.png?
# Downloading page http://xkcd.com798 ...
# Downloading image //imgs.xkcd.com/comics/addiction.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/addiction.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/addiction.png?
# Downloading page http://xkcd.com598 ...
# Downloading image //imgs.xkcd.com/comics/adjectives.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/adjectives.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/adjectives.png?
# Downloading page http://xkcd.com799 ...
# Downloading image //imgs.xkcd.com/comics/porn.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/porn.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/porn.png?
# Downloading page http://xkcd.com599 ...
# Downloading image //imgs.xkcd.com/comics/stephen_hawking.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/stephen_hawking.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/stephen_hawking.png?
# Downloading image //imgs.xkcd.com/comics/apocalypse.png ...
# There was a problem: Invalid URL '//imgs.xkcd.com/comics/apocalypse.png': No schema supplied. Perhaps you meant http:////imgs.xkcd.com/comics/apocalypse.png?
#
# Done.

# %% [markdown]
# ## Launching other programs from Python

# %%
import subprocess
subprocess.Popen('/Applications/Calculator.app/Contents/MacOS/Calculator')

# %% [markdown]
# ## Passing Command Line Arguments to Popen()

# %%
subprocess.Popen(['/Applications/Notes.app/Contents/MacOS/Notes', 'Hello'])

# %% [markdown]
# ## Opening Files with Default Applications

# %%
file_obj = open('hello.txt', 'w')
file_obj.write('Hello World!')
# Out:
# 12

# %%
file_obj.close()

subprocess.Popen(['open', 'hello.txt'], shell=False) # because os X

# %%
subprocess.Popen(['open', '/Applications/Calculator.app/'])

# %% [markdown]
# ## Project: Simpple Countdown Program

# %%
# %load countdown.py
#!/usr/bin/env python3
"""
Created on Mon Aug 26 00:13:02 2019

@author: Soo Hyeon Kim
- a simple countdown script
"""
import time, subprocess

time_left = 60
while time_left > 0:
    print(time_left, end='')
    time.sleep(1)
    time_left -= 1

# TODO: At the end of the countdown, play a sound file
subprocess.Popen(['open', 'alam.wav'], shell=False)
# Out:
# 605958575655545352515049484746454443424140393837363534333231302928272625242322212019181716151413121110987654321

# %% [markdown]
# # Practice Projects
# ## Prettified stopwatch

# %%
# %load pretty_stopwatch.py
#!/usr/bin/env python3
"""
Created on Mon Aug 26 00:37:20 2019

@author: Soo Hyeon Kim
"""

import time, pyperclip

# Display the program's instructions.
input('Press ENTER to begin. Afterwards, press ENTER to "click" the stopwatch'
      'Press Ctrl-C to quit. or simply type "q" or "quit"')
print('\nStarted.')
start_time = time.time()
last_time = start_time
lap_num = 1
copy_str = ''
# TODO: Start tracking the lap time.
try:
    while True:
        
        input_ = input()
        lap_time = str(round(time.time() - last_time, 2)).rjust(6)
        total_time = str(round(time.time() - start_time, 2)).rjust(6)
        
        print('Lap #{}: {} ({})'.format(str(lap_num).rjust(2), total_time, lap_time, end=''))
        
        copy_str = copy_str + \
                            'Lap #{}: {} ({})\n'.format(str(lap_num).rjust(2), \
                            total_time, lap_time)
        
        if input_.lower() in ['quit', 'q']:
            break
              
        lap_num += 1
        last_time = time.time()
        
except KeyboardInterrupt:
    # Handle the Ctrl-C exception to keep its error message from displaying.
    print('\nDone. Your result is copied to the clipboard.'
          'If you want to paste it, use ctrl+v')
    
pyperclip.copy(copy_str)
# Out:
# Press ENTER to begin. Afterwards, press ENTER to "click" the stopwatchPress Ctrl-C to quit. or simply type "q" or "quit"
#
# Started.
#
# Lap # 1:   1.07 (  1.07)
#
# Lap # 2:   6.55 (  5.49)
#
# Lap # 3:  11.58 (  5.03)
#
# Lap # 4:   23.6 ( 12.02)
#
# Lap # 5:  26.67 (  3.07)
# quit
# Lap # 6:   37.4 ( 10.73)

# %% [markdown]
# ### ctrl + v
# Lap # 1:   1.07 (  1.07)
#
# Lap # 2:   6.55 (  5.49)
#
# Lap # 3:  11.58 (  5.03)
#
# Lap # 4:   23.6 ( 12.02)
#
# Lap # 5:  26.67 (  3.07)
#
# Lap # 6:   37.4 ( 10.73)
